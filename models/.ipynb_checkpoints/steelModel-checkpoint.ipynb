# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor

# %%
df = pd.read_csv("steel_800_rows_cleaned.csv")

print(df.shape)
df.head()
# Out:
# (625, 14)
#    steel_8mm_mt  steel_10mm_mt  steel_12mm_mt  steel_16mm_mt  steel_20mm_mt  \
# 0           0.0            0.0        39.2965         0.0000         0.0000
# 1           0.0            0.0         0.0000         0.0000         2.1715
# 2           0.0            0.0        37.8381         0.0000         0.0000
# 3           0.0            0.0        40.2714         0.0000         0.0000
# 4           0.0            0.0        31.1647         4.3508         0.0000
#
#    steel_25mm_mt  steel_32mm_mt  total_procured_mt  built_up_area_sqft  \
# 0            0.0            0.0            39.2965         177289.8849
# 1            0.0            0.0             2.1715         109088.4357
# 2            0.0            0.0            37.8381         176920.1976
# 3            0.0            0.0            40.2714         161698.2952
# 4            0.0            0.0            35.5155         121214.2026
#
#    floors  consumption_mt  waste_mt  waste_percent  relevance_score
# ...

# %%
steel_cols = [col for col in df.columns if col.startswith("steel_") and col.endswith("_mt")]
steel_cols
# Out:
# ['steel_8mm_mt',
#  'steel_10mm_mt',
#  'steel_12mm_mt',
#  'steel_16mm_mt',
#  'steel_20mm_mt',
#  'steel_25mm_mt',
#  'steel_32mm_mt']

# %%
feature_cols = (
    steel_cols
    + ["total_procured_mt", "built_up_area_sqft"]
)

X = df[feature_cols]
y = df["waste_mt"]
sample_weights = df["relevance_score"]

# %%
sample_weights = sample_weights / sample_weights.mean()

# %%
X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(
    X,
    y,
    sample_weights,
    test_size=0.10,
    random_state=42
)

# %%
model = XGBRegressor(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="reg:squarederror",
    random_state=42
)

# %%
model.fit(
    X_train,
    y_train,
    sample_weight=w_train
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

weighted_rmse = np.sqrt(
    np.average((y_test - y_pred) ** 2, weights=w_test)
)

print(f"RMSE: {rmse:.4f}")
print(f"Weighted RMSE (relevance-aware): {weighted_rmse:.4f}")
# Out:
# RMSE: 1.6639
# Weighted RMSE (relevance-aware): 1.6525

# %%
feature_importance = pd.Series(
    model.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

feature_importance
# Out:
# total_procured_mt     0.313712
# built_up_area_sqft    0.113433
# steel_12mm_mt         0.109377
# steel_10mm_mt         0.103846
# steel_20mm_mt         0.101836
# steel_16mm_mt         0.097548
# steel_8mm_mt          0.076079
# steel_25mm_mt         0.067140
# steel_32mm_mt         0.017028
# dtype: float32

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.xlabel("Actual Waste (mt)")
plt.ylabel("Predicted Waste (mt)")
plt.title("Predicted vs Actual Waste")

plt.tight_layout()
plt.show()

# %%
residuals = y_test - y_pred

plt.figure(figsize=(6, 4))
plt.hist(residuals, bins=25, edgecolor="black")
plt.axvline(0, linestyle="--")

plt.xlabel("Residual (Actual − Predicted)")
plt.ylabel("Frequency")
plt.title("Residual Distribution")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(y_pred, residuals, alpha=0.7)
plt.axhline(0, linestyle="--")

plt.xlabel("Predicted Waste (mt)")
plt.ylabel("Residual")
plt.title("Residuals vs Predicted Values")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(y_pred, residuals, s=w_test * 20, alpha=0.6)
plt.axhline(0, linestyle="--")

plt.xlabel("Predicted Waste (mt)")
plt.ylabel("Residual")
plt.title("Residuals Weighted by Relevance Score")

plt.tight_layout()
plt.show()

# %%
top_k = 10
top_features = feature_importance.head(top_k)

plt.figure(figsize=(8, 4))
top_features.sort_values().plot(kind="barh")

plt.xlabel("Importance Score")
plt.title("Top Feature Importances")

plt.tight_layout()
plt.show()

# %%
import joblib

joblib.dump(model, "steelModel_v1.joblib")
# Out:
# ['steelModel_v1.joblib']
